# %%
# !python findroute.py --calles Archivos\datos.txt -s 1 -g 10 -m ids
# Out:
# 1::[(3, 5.0), (4, 4.0), (8, 2.0)]
# 2::[(5, 5.0), (7, 9.0), (8, 1.0), (10, 7.0)]
# 3::[(1, 5.0), (6, 6.0)]
# 4::[(1, 4.0), (5, 7.0)]
# 5::[(2, 5.0), (4, 7.0), (6, 7.0), (9, 8.0)]
# 6::[(3, 6.0), (5, 7.0), (9, 1.0)]
# 7::[(2, 9.0), (10, 3.0), (8, 5.0)]
# 8::[(1, 2.0), (2, 1.0), (7, 5.0)]
# 9::[(5, 8.0), (6, 1.0), (10, 2.0)]
# 10::[(2, 7.0), (7, 3.0), (9, 2.0)]
# ********************************************************
# set()
# 1
# -----------------------------------------------
# 1
# [(3, 5.0), (4, 4.0), (8, 2.0)]
# ['go3', 'go4', 'go8']
# -------------------------------
# 3
# 4
# 8
# -------------------------------
# ********************************************************
# {'1'}
# 3
# 4
# 8
# -----------------------------------------------
# 3
# [(1, 5.0), (6, 6.0)]
# ['go1', 'go6']
# -------------------------------
# 1
# 6
# -------------------------------
# ********************************************************
# {'3', '1'}
# 4
# 8
# 6
# ...

# %%
cadena="go103"
print(cadena[2:])
# Out:
# 103
